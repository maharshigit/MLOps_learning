# %%
# Q1. Refactoring

# %%
# python3 question-1.py 2023 3

# %%
from IPython.display import Image, display

display(Image(filename="/home/vjanga1/pyspark/mlops-zoomcamp/cohorts/2025/06-best-practices/homework/pics/1.png"))

# %%
# Q2. Installing pytest

# %%
# Q3. Writing first unit test

# %%
# mlops-zoomcamp/cohorts/2025/06-best-practices/homework/test/test_prepation.py

# %%
img_path = "pics/2.png"  # can be .jpg too
display(Image(filename=img_path))

# %%
#Q4. Mocking S3 with Localstack

# %%
img_path = "pics/3.png"  # can be .jpg too
display(Image(filename=img_path))

# %%
# homework/question_4.py

# %%
# Q5. Creating test data

# %%
# mlops-zoomcamp/cohorts/2025/06-best-practices/homework/test/integration_test.py

# %%
img_path = "pics/4.png"  # can be .jpg too
display(Image(filename=img_path))

# %%
# Q6. Finish the integration test

# %%
img_path = "pics/5.png"  # can be .jpg too
display(Image(filename=img_path))
